# %%
import math

# %%
print(math.pow(4,100))
# Out:
# 1.6069380442589903e+60

# %%
print(100-90)
# Out:
# 10

# %%
a = 1
b = -5
c = 6

delta = (b ** 2) - 4 * a * c

x = ((-1 * b) + math.sqrt(delta)) / (2 * a)

print(x)
# Out:
# 3.0

# %%
# Arredonda
print(math.ceil(2.5)) # Cima
print(math.trunc(2.5)) # Baixo
# Out:
# 3
# 2

# %%
import os

if os.path.exists("arquivo.txt"):
    os.remove("arquivo.txt")
else:
    print('O arquivo não existe')

# %%
os.rmdir("aaaaa")
